# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
url = 'https://raw.githubusercontent.com/PedroCosDi/p4dataedgeflow/main/queimadas.csv'
df = pd.read_csv(url, encoding='ISO-8859-1', sep=';')

# %%
print(df.head())
# Out:
#       date                     class  focuses           uf
# 0  2024/01  Desmatamento Consolidado        3         ACRE
# 1  2024/01  Desmatamento Consolidado        1        AMAPÁ
# 2  2024/01  Desmatamento Consolidado       22     AMAZONAS
# 3  2024/01  Desmatamento Consolidado       69     MARANHÃO
# 4  2024/01  Desmatamento Consolidado      274  MATO GROSSO

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1977 entries, 0 to 1976
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     1977 non-null   object
#  1   class    1977 non-null   object
#  2   focuses  1977 non-null   int64
#  3   uf       1977 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 61.9+ KB
# None

# %%
print(df.describe())
# Out:
#            focuses
# count  1977.000000
# mean    235.412747
# std     647.066236
# min       1.000000
# 25%       6.000000
# 50%      27.000000
# 75%     156.000000
# max    7803.000000

# %%
for column in df.columns:
    print(df[column].unique())
# Out:
# ['2024/01' '2023/01' '2023/02' '2023/03' '2023/04' '2023/05' '2023/06'
#  '2023/07' '2023/08' '2023/09' '2023/10' '2023/11' '2023/12' '2022/01'
#  '2022/02' '2022/03' '2022/04' '2022/05' '2022/06' '2022/07' '2022/08'
#  '2022/09' '2022/10' '2022/11' '2022/12' '2021/01' '2021/02' '2021/03'
#  '2021/04' '2021/05' '2021/06' '2021/07' '2021/08' '2021/09' '2021/10'
#  '2021/11' '2021/12' '2020/01' '2020/02' '2020/03' '2020/04' '2020/05'
#  '2020/06' '2020/07' '2020/08' '2020/09' '2020/10' '2020/11' '2020/12'
#  '2019/08' '2019/09' '2019/10' '2019/11' '2019/12']
# ['Desmatamento Consolidado' 'Desmatamento Recente' 'Floresta' 'Outros'
#  'Vegetacao Secundaria']
# [   3    1   22   69  274  308   26   59    6   27    5   64   67    4
#    44   54    7   70  115  194   37   15   32   38  285   20   35   24
#   105    2    9   94  148   29   31   25   19   57    8  108   17  118
#    11   77  270   49   13   39   16   12   88  250   62   18   45  149
#   239  271   30   92   10   23   68   79  379  123  453  312   33   14
#   122   40  488  310  629   52  549  140   84   34  209  153  178  227
#   575  156  247  262   50  501  203  451   96  202  739  139  319 1701
#   345  179 1629  497 1751  633  883 2361   48  687 2237  560   46  182
#    60  304   85   42  121  563  732   91 1006  290  776 2788  493  340
#  1770  900 1893  748 1989   83 3190  104  930 3154  885   72  306  299
#   135  637  363  726  145  155  944  161   61  611  730  455 3067   65
#   236  789  277 1594  237 1036  398 1796  183  323 4296  326   98  245
#   120  772  231  248  417  226   55 1647   74  136  795  301 2637  215
#   129  191  913   99   90  199  192 2744  228  650  101  113   97  606
#   420  293  400 1288  471  333  946   21  198  213   76  126  641   51
#    36  142  241  433   73   41   89  261  112  130  474   80  982   58
#   388   43  934  128  216  292  541  147  217  947  655  736  337  151
#   134   28   87  407  920  159  955 2815  427 1795 6122 3592 7803 2687
#   671 1014  943  173  269   86  642 1308  286 1745 3514  771 4656 5871
#   116 3150 6724 3731  746  903 1578 1160  353  242  428  138  234  868
#   313  770  362 2354  819  195  356 3544  461  117  418  238   56  278
#   875  223  831  482 1827  763  137  220  352  276  479  375  110  347
#  1215  468  102  187  111   78  366  926  332  645   63  330  109  124
#    47  298  307   71  291  530  254  722  127   93  305  490  272  688
#   475  537  133  103  193 1289  160  884 1762 2081 5830 1928 4806 3040
#   346  902  581  663  211  512  477  208  684  580  905 1297  625 2725
#  1685 1384 1901 1688  403  300  189  170  219  150  164  544  513 1314
#   440  737  987  162  365 2061  968   75  172  157   81  505  713 1406
#   107   95 1292   66  316  740  327  152  206  175  441  165  392  553
#   519  144  311  995  167  207 1167 1098  218  158  119  204  357  598
#  1567  931 2890  561 2413 4803 1740 6401 1972  344  411  786  114  571
#   567 1020  233 2670 3940  965 2279 2343 2961 4429 2598  359  459 2013
#  1239  531  639  154  387  255  341  318  469  942  623 1137  846 3539
#  1320  377  176  867  766  454 1307  106  915  569  951  707 1444 3421
#  1303 2071 3989 2710 5134 3472  511  696  303  185  483  212  616  358
#   491  773 1678 1809  964 2048 2145 1793 2195  287  288  822  425  336
#   320  273  184  253  174  514 1343 1760  279   53  436 1054  416 2741
#  3059  294  381 1149  532  787  556]
# ['ACRE' 'AMAPÁ' 'AMAZONAS' 'MARANHÃO' 'MATO GROSSO' 'PARÁ' 'RONDÔNIA'
#  'RORAIMA' 'TOCANTINS']

# %%
# Gráfico de barras para contagem de cada UF
uf_counts = df['uf'].value_counts().reset_index()
uf_counts.columns = ['uf', 'count']
fig = px.bar(uf_counts, x='uf', y='count', title='Contagem de ocorrências por estado',
             labels={'count': 'Número de ocorrências'}, color='uf')
fig.update_traces(marker_line_width=1, marker_line_color="black")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1d8ab245-3e07-4512-ba14-716312aad0aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d8ab245-3e07-4512-ba14-716312aad0aa")) {                    Plotly.newPlot(                        "1d8ab245-3e07-4512-ba14-716312aad0aa",                        [{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MATO GROSSO","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"MATO GROSSO","offsetgroup":"MATO GROSSO","orientation":"v","showlegend":true,"textposition":"auto","x":["MATO GROSSO"],"xaxis":"x","y":[270],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PAR\u00c1","marker":{"color":"#EF553B","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"PAR\u00c1","offsetgroup":"PAR\u00c1","orientation":"v","showlegend":true,"textposition":"auto","x":["PAR\u00c1"],"xaxis":"x","y":[267],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AMAZONAS","marker":{"color":"#00cc96","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"AMAZONAS","offsetgroup":"AMAZONAS","orientation":"v","showlegend":true,"textposition":"auto","x":["AMAZONAS"],"xaxis":"x","y":[258],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROND\u00d4NIA","marker":{"color":"#ab63fa","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"ROND\u00d4NIA","offsetgroup":"ROND\u00d4NIA","orientation":"v","showlegend":true,"textposition":"auto","x":["ROND\u00d4NIA"],"xaxis":"x","y":[247],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RORAIMA","marker":{"color":"#FFA15A","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"RORAIMA","offsetgroup":"RORAIMA","orientation":"v","showlegend":true,"textposition":"auto","x":["RORAIMA"],"xaxis":"x","y":[230],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MARANH\u00c3O","marker":{"color":"#19d3f3","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"MARANH\u00c3O","offsetgroup":"MARANH\u00c3O","orientation":"v","showlegend":true,"textposition":"auto","x":["MARANH\u00c3O"],"xaxis":"x","y":[224],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TOCANTINS","marker":{"color":"#FF6692","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"TOCANTINS","offsetgroup":"TOCANTINS","orientation":"v","showlegend":true,"textposition":"auto","x":["TOCANTINS"],"xaxis":"x","y":[167],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ACRE","marker":{"color":"#B6E880","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"ACRE","offsetgroup":"ACRE","orientation":"v","showlegend":true,"textposition":"auto","x":["ACRE"],"xaxis":"x","y":[165],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"uf ...

# %%
# Gráfico de barras para contagem de cada Class
class_counts = df['class'].value_counts().reset_index()
class_counts.columns = ['class', 'count']
fig = px.bar(class_counts, x='class', y='count', title='Contagem de ocorrências por classe',
             labels={'count': 'Número de ocorrências'}, color='class')
fig.update_traces(marker_line_width=1, marker_line_color="black")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7f948ca2-b41a-4c33-aef8-76e86ba407ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f948ca2-b41a-4c33-aef8-76e86ba407ec")) {                    Plotly.newPlot(                        "7f948ca2-b41a-4c33-aef8-76e86ba407ec",                        [{"alignmentgroup":"True","hovertemplate":"class=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desmatamento Consolidado","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Desmatamento Consolidado","offsetgroup":"Desmatamento Consolidado","orientation":"v","showlegend":true,"textposition":"auto","x":["Desmatamento Consolidado"],"xaxis":"x","y":[440],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"class=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desmatamento Recente","marker":{"color":"#EF553B","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Desmatamento Recente","offsetgroup":"Desmatamento Recente","orientation":"v","showlegend":true,"textposition":"auto","x":["Desmatamento Recente"],"xaxis":"x","y":[399],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"class=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vegetacao Secundaria","marker":{"color":"#00cc96","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Vegetacao Secundaria","offsetgroup":"Vegetacao Secundaria","orientation":"v","showlegend":true,"textposition":"auto","x":["Vegetacao Secundaria"],"xaxis":"x","y":[391],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"class=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Floresta","marker":{"color":"#ab63fa","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Floresta","offsetgroup":"Floresta","orientation":"v","showlegend":true,"textposition":"auto","x":["Floresta"],"xaxis":"x","y":[377],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"class=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Outros","marker":{"color":"#FFA15A","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Outros","offsetgroup":"Outros","orientation":"v","showlegend":true,"textposition":"auto","x":["Outros"],"xaxis":"x","y":[370],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"], ...

# %%
# Gráfico de barras agrupadas para distribuição de Class por UF
uf_class_counts = df.groupby(['uf', 'class']).size().unstack(fill_value=0).reset_index()
fig = px.bar(uf_class_counts, x='uf', y=uf_class_counts.columns[1:], title='Distribuição de classe por estado',
             labels={'value': 'Número de ocorrências', 'class': 'Classe'}, barmode='stack')
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.update_traces(marker_line_width=1, marker_line_color="black")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="58d32e7f-5c09-482a-8861-a63a6848b8f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58d32e7f-5c09-482a-8861-a63a6848b8f3")) {                    Plotly.newPlot(                        "58d32e7f-5c09-482a-8861-a63a6848b8f3",                        [{"alignmentgroup":"True","hovertemplate":"variable=Desmatamento Consolidado\u003cbr\u003euf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desmatamento Consolidado","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Desmatamento Consolidado","offsetgroup":"Desmatamento Consolidado","orientation":"v","showlegend":true,"textposition":"auto","x":["ACRE","AMAP\u00c1","AMAZONAS","MARANH\u00c3O","MATO GROSSO","PAR\u00c1","ROND\u00d4NIA","RORAIMA","TOCANTINS"],"xaxis":"x","y":[46,30,54,52,54,54,54,47,49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Desmatamento Recente\u003cbr\u003euf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desmatamento Recente","marker":{"color":"#EF553B","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Desmatamento Recente","offsetgroup":"Desmatamento Recente","orientation":"v","showlegend":true,"textposition":"auto","x":["ACRE","AMAP\u00c1","AMAZONAS","MARANH\u00c3O","MATO GROSSO","PAR\u00c1","ROND\u00d4NIA","RORAIMA","TOCANTINS"],"xaxis":"x","y":[41,20,53,47,54,53,54,46,31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Floresta\u003cbr\u003euf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Floresta","marker":{"color":"#00cc96","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Floresta","offsetgroup":"Floresta","orientation":"v","showlegend":true,"textposition":"auto","x":["ACRE","AMAP\u00c1","AMAZONAS","MARANH\u00c3O","MATO GROSSO","PAR\u00c1","ROND\u00d4NIA","RORAIMA","TOCANTINS"],"xaxis":"x","y":[36,32,51,38,54,53,45,48,20],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Outros\u003cbr\u003euf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Outros","marker":{"color":"#ab63fa","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Outros","offsetgroup":"Outros","orientation":"v","showlegend":true,"textposition":"auto","x":["ACRE","AMAP\u00c1","AMAZONAS","MARANH\u00c3O","MATO GROSSO","PAR\u00c1","ROND\u00d4NIA","RORAIMA","TOCANTINS"],"xaxis":"x","y":[3,44,48,41,54,54,45,53,28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Vegetacao Secundaria\u003cbr\u003euf=%{x}\u003cbr\u003eN\u00famero de ocorr\u00eancias=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vegetacao Secundaria","marker":{"color":"#FFA15A","pattern":{"shape":""},"line":{"color":"black","width":1}},"name":"Vegetacao Secundaria","offsetgroup":"Vegetacao Secundaria","orientation":"v","showlegend":true,"textposition":"auto","x":["ACRE","AMAP\u00c1","AMAZONAS","MARANH\u00c3O","MATO GROSSO","PAR\u00c1","ROND\u00d4NIA","RORAIMA","TOCANTINS"],"xaxis":"x","y":[39,23,52,46,54,53,49,36,39],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %%
# Convertendo a coluna 'date' para o tipo datetime
df['date'] = pd.to_datetime(df['date'])

# Ordenando o DataFrame pelo 'date'
df_sorted = df.sort_values(by='date')

# Plotando o gráfico de linha
fig = px.line(df_sorted, x='date', y='focuses', color='uf', title='Número de focos por estado ao longo do tempo')
fig.update_layout(xaxis_title='Data', yaxis_title='Número de focos')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="77099419-f553-42c4-803f-9306f5ba9e8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77099419-f553-42c4-803f-9306f5ba9e8d")) {                    Plotly.newPlot(                        "77099419-f553-42c4-803f-9306f5ba9e8d",                        [{"hovertemplate":"uf=PAR\u00c1\u003cbr\u003edate=%{x}\u003cbr\u003efocuses=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PAR\u00c1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PAR\u00c1","showlegend":true,"x":["2019-08-01T00:00:00","2019-08-01T00:00:00","2019-08-01T00:00:00","2019-08-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-09-01T00:00:00","2019-09-01T00:00:00","2019-09-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-10-01T00:00:00","2019-10-01T00:00:00","2019-10-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-11-01T00:00:00","2019-11-01T00:00:00","2019-11-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2019-12-01T00:00:00","2019-12-01T00:00:00","2019-12-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-01-01T00:00:00","2020-01-01T00:00:00","2020-01-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-02-01T00:00:00","2020-02-01T00:00:00","2020-02-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-03-01T00:00:00","2020-03-01T00:00:00","2020-03-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-04-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-05-01T00:00:00","2020-05-01T00:00:00","2020-05-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-06-01T00:00:00","2020-06-01T00:00:00","2020-06-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-07-01T00:00:00","2020-07-01T00:00:00","2020-07-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-08-01T00:00:00","2020-08-01T00:00:00","2020-08-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-09-01T00:00:00","2020-09-01T00:00:00","2020-09-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-10-01T00:00:00","2020-10-01T00:00:00","2020-10-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-11-01T00:00:00","2020-11-01T00:00:00","2020-11-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2020-12-01T00:00:00","2020-12-01T00:00:00","2020-12-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-01-01T00:00:00","2021-01-01T00:00:00","2021-01-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-02-01T00:00:00","2021-02-01T00:00:00","2021-02-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-03-01T00:00:00","2021-03-01T00:00:00","2021-03-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-04-01T00:00:00","2021-04-01T00:00:00","2021-04-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-05-01T00:00:00","2021-05-01T00:00:00","2021-05-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-06-01T00:00:00","2021-06-01T00:00:00","2021-06-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-07-01T00:00:00","2021-07-01T00:00:00","2021-07-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-09-01T00:00:00","2021-09-01T00:00:00","2021-09-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-10-01T00:00:00","2021-10-01T00:00:00","2021-10-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-11-01T00:00:00","2021-11-01T00:00:00","2021-11-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2021-12-01T00:00:00","2021-12-01T00:00:00","2021-12-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00: ...
